# %%
import pandas as pd
df = pd.read_html("https://www.bank.lv/statistika/dati-statistika/valutu-kursi/aktualie")
print(df)  #izdrukāju visas datu masīvā esošās tabulas
# Out:
# [                                     0       1    2           3
# 0      Apvienoto Arābu Emirātu dirhēms     NaN  AED    0.140000
# 1                   Austrālijas dolārs     NaN  AUD    0.457000
# 2                      Bulgārijas leva     NaN  BGN    0.359000
# 3                 Baltkrievijas rublis  1000.0  BYR    0.054300
# 4                       Kanādas dolārs     NaN  CAD    0.483000
# 5                       Šveices franks     NaN  CHF    0.573000
# 6                 Ķīnas juaņa renminbi     NaN  CNY    0.084900
# 7                        Čehijas krona     NaN  CZK    0.025400
# 8                        Dānijas krona     NaN  DKK    0.094200
# 9                      Ēģiptes mārciņa     NaN  EGP    0.074600
# 10                                Eiro     NaN  EUR    0.702804
# 11     Lielbritānijas sterliņu mārciņa     NaN  GBP    0.843000
# 12                    Honkongas dolārs     NaN  HKD    0.066500
# 13                     Horvātijas kuna     NaN  HRK    0.092000
# ...

# %%
 print (len(df)) #kopējo tabulu skaits.
# Out:
# 14

# %%
print(df[0]) #izdrukāju tikai pirmo tabulu.
# Out:
#                                      0       1    2           3
# 0      Apvienoto Arābu Emirātu dirhēms     NaN  AED    0.140000
# 1                   Austrālijas dolārs     NaN  AUD    0.457000
# 2                      Bulgārijas leva     NaN  BGN    0.359000
# 3                 Baltkrievijas rublis  1000.0  BYR    0.054300
# 4                       Kanādas dolārs     NaN  CAD    0.483000
# 5                       Šveices franks     NaN  CHF    0.573000
# 6                 Ķīnas juaņa renminbi     NaN  CNY    0.084900
# 7                        Čehijas krona     NaN  CZK    0.025400
# 8                        Dānijas krona     NaN  DKK    0.094200
# 9                      Ēģiptes mārciņa     NaN  EGP    0.074600
# 10                                Eiro     NaN  EUR    0.702804
# 11     Lielbritānijas sterliņu mārciņa     NaN  GBP    0.843000
# 12                    Honkongas dolārs     NaN  HKD    0.066500
# 13                     Horvātijas kuna     NaN  HRK    0.092000
# ...

# %%
print(df[0].head(15)) #izdrukāju 1. tabulas pirmās 14 rindas.
# Out:
#                                   0       1    2         3
# 0   Apvienoto Arābu Emirātu dirhēms     NaN  AED  0.140000
# 1                Austrālijas dolārs     NaN  AUD  0.457000
# 2                   Bulgārijas leva     NaN  BGN  0.359000
# 3              Baltkrievijas rublis  1000.0  BYR  0.054300
# 4                    Kanādas dolārs     NaN  CAD  0.483000
# 5                    Šveices franks     NaN  CHF  0.573000
# 6              Ķīnas juaņa renminbi     NaN  CNY  0.084900
# 7                     Čehijas krona     NaN  CZK  0.025400
# 8                     Dānijas krona     NaN  DKK  0.094200
# 9                   Ēģiptes mārciņa     NaN  EGP  0.074600
# 10                             Eiro     NaN  EUR  0.702804
# 11  Lielbritānijas sterliņu mārciņa     NaN  GBP  0.843000
# 12                 Honkongas dolārs     NaN  HKD  0.066500
# 13                  Horvātijas kuna     NaN  HRK  0.092000
# 14                Ungārijas forints   100.0  HUF  0.235000

# %%
df[0].to_csv("LB1.csv") #saglabāju datus kā csv failu
